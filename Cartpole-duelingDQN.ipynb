# %% [markdown]
# # Train Cartpole Balancing problem in OpenAI Env using Dueling DQN network along with prioritized memory replay using sum tree

# %%
#Initialize
import math, random
import gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import torch.autograd as Variable
import torch.nn.functional as F
from collections import deque

env = gym.make("CartPole-v0")

epsilon = 1.0
epsilonMin = 0.01
decay = 0.999
episodes = 500
batch_size = 32
gamma = 0.99
goal_steps = 200

# %%
# Network
class DuelingDQN(nn.Module):
    def __init__(self, num_inputs, num_outputs):
        super(DuelingDQN, self).__init__()
        self.fc1 = nn.Linear(num_inputs, 128)
        
        self.a1 = nn.Linear(128, 128)
        self.a2 = nn.Linear(128, num_outputs)
        
        self.val1 = nn.Linear(128, 128)
        self.val2 = nn.Linear(128, 1)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        
        adv = F.relu(self.a1(x))
        adv = self.a2(adv)

        val = F.relu(self.val1(x))
        val = self.val2(val)
        return val + adv - adv.mean()
    
    def act(self, state, epsilon):
        if random.random() > epsilon:
            state = torch.FloatTensor(state).unsqueeze(0)
            q_value = self.forward(state)
            action = q_value.max(1)[1].data[0].numpy()
        else:
            action = env.action_space.sample()
        return action

# %%
model1 = DuelingDQN(env.observation_space.shape[0], env.action_space.n)
model2 = DuelingDQN(env.observation_space.shape[0], env.action_space.n)

optimizer = optim.Adam(model1.parameters())
def sync(model1, model2):
    model2.load_state_dict(model1.state_dict())

sync(model1, model2)

# %%
class SumTree:
    write = 0
    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2*capacity - 1)
        self.data = np.zeros(capacity, dtype=object)

    def _propagate(self, idx, change):
        parent = (idx-1)//2

        self.tree[parent] += change

        if parent != 0:
            self._propagate(parent, change)

    def _retrieve(self, idx, s):
        left = 2*idx + 1
        right = left + 1

        if left >= len(self.tree):
            return idx

        if s <= self.tree[left]:
            return self._retrieve(left, s)
        else:
            return self._retrieve(right, s-self.tree[left])

    def total(self):
        return self.tree[0]

    def add(self, p, data):
        idx = self.write + self.capacity - 1

        self.data[self.write] = data
        self.update(idx, p)

        self.write += 1
        if self.write >= self.capacity:
            self.write = 0

    def update(self, idx, p):
        change = p - self.tree[idx]
        self.tree[idx] = p
        self._propagate(idx, change)

    def get(self, s):
        idx = self._retrieve(0, s)
        dataIdx = idx - self.capacity + 1
        return (idx, self.tree[idx], self.data[dataIdx])

# %%
# Replay memory
class Memory:
    samples = []
    def __init__(self, capacity):
        self.tree = SumTree(capacity)
        self.e = 0.01
        self.a = 0.6

    def _getPriority(self, error):
        return (error + self.e)**self.a

    def add(self, error, sample):
        p = self._getPriority(error)
        self.tree.add(p, sample)

    def sample(self, n):
        batch = []
        segment = self.tree.total()/n

        for i in range(n):
            a = segment*1
            b = segment * (i + 1)
            s = random.uniform(a,b)
            (idx, p, data) = self.tree.get(s)
            batch.append((idx, data))
            
        return batch

    def update(self, idx, error):
        p = self._getPriority(error)
        self.tree.update(idx, p)

# %%
# Estimating error
def get_error(state, action, reward, next_state, done):
    state = torch.FloatTensor(np.float32(state))
    next_state = torch.FloatTensor(np.float32(next_state))
    action = torch.LongTensor(action)
#     print(action.unsqueeze(1))
    reward = torch.FloatTensor(reward)
    done = torch.FloatTensor(done)
    q_values = model1(state)
    next_q_values = model1(next_state)
#     print(next_q_values.shape)
    next_q_values2 = model2(next_state)
    q_value = q_values.gather(1, action.unsqueeze(1)).squeeze(1)
    next_q_value = next_q_values2.gather(1, torch.max(next_q_values, 1)[1].unsqueeze(1)).squeeze(1)
    expected_q_value = reward + gamma * next_q_value * (1 - done)
    error = abs(q_value - expected_q_value)
    return error

# %%
memory = Memory(10000)

for idx in range(episodes):
    state = env.reset()
    total_reward = 0
    done = False
    while not done:
        action = int(model1.act(state, epsilon))
        next_state, reward, done, _ = env.step(action)
        exp = state, action, reward, next_state, done

        state = torch.FloatTensor(np.float32(state))
        next_state = torch.FloatTensor(np.float32(next_state))
        q_values = model1(state)
        next_q_values = model1(next_state)
        next_q_values2 = model2(next_state)

        q_value = q_values[action].squeeze(0)
        a = int(torch.max(next_q_values, 0)[1].numpy())
        next_q_value = next_q_values2[a]
        
        expected_q_value = reward + gamma * next_q_value * (1 - done)
        error = float(abs(q_value - expected_q_value).detach().numpy())
        memory.add(error, exp)
        state = next_state
        total_reward += reward
        
        if done:
            done = False
            print("Episode = " + str(idx) + " , Score = " + str(total_reward))
            break
    
    if epsilon > epsilonMin:
        epsilon *= decay
    
    if idx % 100 == 0:
        sync(model1, model2)
        
    if idx > 3:
        batch = memory.sample(batch_size)
        state = [np.array(batch[i][1][0]) for i in range(batch_size)]
        action = np.array([o[1][1] for o in batch])
        reward = np.array([o[1][2] for o in batch])
        next_state = np.array([o[1][3] for o in batch])
        done = np.array([o[1][4] for o in batch])
        d = [0]*32
        for i in range(len(d)):
            if done[i]==True:
                d[i] = 1
            else:
                d[i] = 0
        error = get_error(state, action, reward, next_state, d)
        loss = error.pow(2).mean()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
# Out:
# Episode = 0 , Score = 35.0
# Episode = 1 , Score = 200.0
# Episode = 2 , Score = 187.0
# Episode = 3 , Score = 58.0
# Episode = 4 , Score = 200.0
# Episode = 5 , Score = 131.0
# Episode = 6 , Score = 134.0
# Episode = 7 , Score = 54.0
# Episode = 8 , Score = 115.0
# Episode = 9 , Score = 95.0
# Episode = 10 , Score = 112.0
# Episode = 11 , Score = 11.0
# Episode = 12 , Score = 85.0
# Episode = 13 , Score = 105.0
# Episode = 14 , Score = 27.0
# Episode = 15 , Score = 20.0
# Episode = 16 , Score = 139.0
# Episode = 17 , Score = 97.0
# Episode = 18 , Score = 187.0
# Episode = 19 , Score = 200.0
# Episode = 20 , Score = 118.0
# Episode = 21 , Score = 140.0
# Episode = 22 , Score = 54.0
# Episode = 23 , Score = 112.0
# Episode = 24 , Score = 93.0
# Episode = 25 , Score = 154.0
# Episode = 26 , Score = 138.0
# Episode = 27 , Score = 59.0
# Episode = 28 , Score = 85.0
# Episode = 29 , Score = 124.0
# Episode = 30 , Score = 71.0
# Episode = 31 , Score = 135.0
# Episode = 32 , Score = 83.0
# Episode = 33 , Score = 34.0
# Episode = 34 , Score = 41.0
# Episode = 35 , Score = 156.0
# Episode = 36 , Score = 161.0
# Episode = 37 , Score = 110.0
# Episode = 38 , Score = 184.0
# Episode = 39 , Score = 83.0
# Episode = 40 , Score = 128.0
# Episode = 41 , Score = 132.0
# Episode = 42 , Score = 108.0
# Episode = 43 , Score = 117.0
# Episode = 44 , Score = 165.0
# Episode = 45 , Score = 127.0
# Episode = 46 , Score = 59.0
# Episode = 47 , Score = 157.0
# Episode = 48 , Score = 200.0
# Episode = 49 , Score = 125.0
# Episode = 50 , Score = 155.0
# Episode = 51 , Score = 121.0
# Episode = 52 , Score = 200.0
# Episode = 53 , Score = 129.0
# Episode = 54 , Score = 43.0
# Episode = 55 , Score = 42.0
# Episode = 56 , Score = 186.0
# Episode = 57 , Score = 165.0
# Episode = 58 , Score = 145.0
# Episode = 59 , Score = 165.0
# Episode = 60 , Score = 178.0
# Episode = 61 , Score = 154.0
# Episode = 62 , Score = 185.0
# Episode = 63 , Score = 10.0
# Episode = 64 , Score = 137.0
# Episode = 65 , Score = 134.0
# Episode = 66 , Score = 146.0
# Episode = 67 , Score = 148.0
# Episode = 68 , Score = 120.0
# Episode = 69 , Score = 108.0
# Episode = 70 , Score = 157.0
# Episode = 71 , Score = 159.0
# Episode = 72 , Score = 13.0
# Episode = 73 , Score = 155.0
# Episode = 74 , Score = 133.0
# Episode = 75 , Score = 129.0
# Episode = 76 , Score = 128.0
# Episode = 77 , Score = 137.0
# Episode = 78 , Score = 13.0
# Episode = 79 , Score = 200.0
# Episode = 80 , Score = 139.0
# Episode = 81 , Score = 135.0
# Episode = 82 , Score = 126.0
# Episode = 83 , Score = 111.0
# Episode = 84 , Score = 119.0
# Episode = 85 , Score = 95.0
# Episode = 86 , Score = 125.0
# Episode = 87 , Score = 123.0
# Episode = 88 , Score = 136.0
# Episode = 89 , Score = 147.0
# Episode = 90 , Score = 196.0
# Episode = 91 , Score = 200.0
# Episode = 92 , Score = 109.0
# Episode = 93 , Score = 200.0
# Episode = 94 , Score = 200.0
# Episode = 95 , Score = 19.0
# Episode = 96 , Score = 164.0
# Episode = 97 , Score = 163.0
# Episode = 98 , Score = 200.0
# Episode = 99 , Score = 200.0
# Episode = 100 , Score = 200.0
# Episode = 101 , Score = 200.0
# Episode = 102 , Score = 39.0
# Episode = 103 , Score = 32.0
# Episode = 104 , Score = 200.0
# Episode = 105 , Score = 63.0
# Episode = 106 , Score = 200.0
# Episode = 107 , Score = 161.0
# Episode = 108 , Score = 200.0
# Episode = 109 , Score = 200.0
# Episode = 110 , Score = 200.0
# Episode = 111 , Score = 200.0
# Episode = 112 , Score = 157.0
# Episode = 113 , Score = 161.0
# Episode = 114 , Score = 200.0
# Episode = 115 , Score = 200.0
# Episode = 116 , Score = 72.0
# Episode = 117 , Score = 183.0
# Episode = 118 , Score = 200.0
# Episode = 119 , Score = 200.0
# Episode = 120 , Score = 22.0
# Episode = 121 , Score = 200.0
# Episode = 122 , Score = 200.0
# Episode = 123 , Score = 198.0
# Episode = 124 , Score = 200.0
# Episode = 125 , Score = 90.0
# Episode = 126 , Score = 200.0
# Episode = 127 , Score = 200.0
# Episode = 128 , Score = 200.0
# Episode = 129 , Score = 200.0
# Episode = 130 , Score = 200.0
# Episode = 131 , Score = 200.0
# Episode = 132 , Score = 200.0
# Episode = 133 , Score = 200.0
# Episode = 134 , Score = 200.0
# Episode = 135 , Score = 87.0
# Episode = 136 , Score = 68.0
# Episode = 137 , Score = 200.0
# Episode = 138 , Score = 200.0
# Episode = 139 , Score = 97.0
# Episode = 140 , Score = 200.0
# Episode = 141 , Score = 175.0
# Episode = 142 , Score = 200.0
# Episode = 143 , Score = 33.0
# Episode = 144 , Score = 200.0
# Episode = 145 , Score = 200.0
# Episode = 146 , Score = 200.0
# Episode = 147 , Score = 92.0
# Episode = 148 , Score = 27.0
# Episode = 149 , Score = 57.0
# Episode = 150 , Score = 189.0
# Episode = 151 , Score = 52.0
# Episode = 152 , Score = 172.0
# Episode = 153 , Score = 187.0
# Episode = 154 , Score = 194.0
# Episode = 155 , Score = 200.0
# Episode = 156 , Score = 110.0
# Episode = 157 , Score = 182.0
# Episode = 158 , Score = 138.0
# Episode = 159 , Score = 200.0
# Episode = 160 , Score = 200.0
# Episode = 161 , Score = 200.0
# Episode = 162 , Score = 200.0
# Episode = 163 , Score = 62.0
# Episode = 164 , Score = 74.0
# Episode = 165 , Score = 174.0
# Episode = 166 , Score = 147.0
# Episode = 167 , Score = 16.0
# Episode = 168 , Score = 154.0
# Episode = 169 , Score = 22.0
# Episode = 170 , Score = 105.0
# Episode = 171 , Score = 154.0
# Episode = 172 , Score = 164.0
# Episode = 173 , Score = 117.0
# Episode = 174 , Score = 162.0
# Episode = 175 , Score = 179.0
# Episode = 176 , Score = 133.0
# Episode = 177 , Score = 200.0
# Episode = 178 , Score = 200.0
# Episode = 179 , Score = 200.0
# Episode = 180 , Score = 150.0
# Episode = 181 , Score = 200.0
# Episode = 182 , Score = 181.0
# Episode = 183 , Score = 106.0
# Episode = 184 , Score = 200.0
# Episode = 185 , Score = 200.0
# Episode = 186 , Score = 194.0
# Episode = 187 , Score = 95.0
# Episode = 188 , Score = 199.0
# Episode = 189 , Score = 200.0
# Episode = 190 , Score = 22.0
# Episode = 191 , Score = 139.0
# Episode = 192 , Score = 200.0
# Episode = 193 , Score = 200.0
# Episode = 194 , Score = 101.0
# Episode = 195 , Score = 200.0
# Episode = 196 , Score = 200.0
# Episode = 197 , Score = 200.0
# Episode = 198 , Score = 200.0
# Episode = 199 , Score = 200.0
# Episode = 200 , Score = 200.0
# Episode = 201 , Score = 200.0
# Episode = 202 , Score = 184.0
# Episode = 203 , Score = 93.0
# Episode = 204 , Score = 175.0
# Episode = 205 , Score = 182.0
# Episode = 206 , Score = 21.0
# Episode = 207 , Score = 162.0
# Episode = 208 , Score = 159.0
# Episode = 209 , Score = 147.0
# Episode = 210 , Score = 127.0
# Episode = 211 , Score = 32.0
# Episode = 212 , Score = 171.0
# Episode = 213 , Score = 178.0
# Episode = 214 , Score = 121.0
# Episode = 215 , Score = 200.0
# Episode = 216 , Score = 127.0
# Episode = 217 , Score = 200.0
# Episode = 218 , Score = 200.0
# Episode = 219 , Score = 200.0
# Episode = 220 , Score = 134.0
# Episode = 221 , Score = 200.0
# Episode = 222 , Score = 34.0
# Episode = 223 , Score = 200.0
# Episode = 224 , Score = 200.0
# Episode = 225 , Score = 200.0
# Episode = 226 , Score = 200.0
# Episode = 227 , Score = 200.0
# Episode = 228 , Score = 200.0
# Episode = 229 , Score = 200.0
# Episode = 230 , Score = 200.0
# Episode = 231 , Score = 67.0
# Episode = 232 , Score = 200.0
# Episode = 233 , Score = 200.0
# Episode = 234 , Score = 195.0
# Episode = 235 , Score = 200.0
# Episode = 236 , Score = 200.0
# Episode = 237 , Score = 200.0
# Episode = 238 , Score = 188.0
# Episode = 239 , Score = 200.0
# Episode = 240 , Score = 13.0
# Episode = 241 , Score = 200.0
# Episode = 242 , Score = 200.0
# Episode = 243 , Score = 192.0
# Episode = 244 , Score = 169.0
# Episode = 245 , Score = 164.0
# Episode = 246 , Score = 34.0
# Episode = 247 , Score = 163.0
# Episode = 248 , Score = 157.0
# Episode = 249 , Score = 24.0
# Episode = 250 , Score = 185.0
# Episode = 251 , Score = 200.0
# Episode = 252 , Score = 193.0
# Episode = 253 , Score = 200.0
# Episode = 254 , Score = 79.0
# Episode = 255 , Score = 200.0
# Episode = 256 , Score = 200.0
# Episode = 257 , Score = 200.0
# Episode = 258 , Score = 200.0
# Episode = 259 , Score = 200.0
# Episode = 260 , Score = 200.0
# Episode = 261 , Score = 200.0
# Episode = 262 , Score = 87.0
# Episode = 263 , Score = 200.0
# Episode = 264 , Score = 176.0
# Episode = 265 , Score = 132.0
# Episode = 266 , Score = 200.0
# Episode = 267 , Score = 50.0
# Episode = 268 , Score = 56.0
# Episode = 269 , Score = 150.0
# Episode = 270 , Score = 164.0
# Episode = 271 , Score = 177.0
# Episode = 272 , Score = 119.0
# Episode = 273 , Score = 145.0
# Episode = 274 , Score = 159.0
# Episode = 275 , Score = 158.0
# Episode = 276 , Score = 140.0
# Episode = 277 , Score = 20.0
# Episode = 278 , Score = 98.0
# Episode = 279 , Score = 143.0
# Episode = 280 , Score = 141.0
# Episode = 281 , Score = 123.0
# Episode = 282 , Score = 147.0
# Episode = 283 , Score = 136.0
# Episode = 284 , Score = 17.0
# Episode = 285 , Score = 155.0
# Episode = 286 , Score = 177.0
# Episode = 287 , Score = 189.0
# Episode = 288 , Score = 188.0
# Episode = 289 , Score = 200.0
# Episode = 290 , Score = 200.0
# Episode = 291 , Score = 200.0
# Episode = 292 , Score = 200.0
# Episode = 293 , Score = 200.0
# Episode = 294 , Score = 200.0
# Episode = 295 , Score = 200.0
# Episode = 296 , Score = 200.0
# Episode = 297 , Score = 200.0
# Episode = 298 , Score = 200.0
# Episode = 299 , Score = 200.0
# Episode = 300 , Score = 200.0
# Episode = 301 , Score = 200.0
# Episode = 302 , Score = 57.0
# Episode = 303 , Score = 40.0
# Episode = 304 , Score = 194.0
# Episode = 305 , Score = 161.0
# Episode = 306 , Score = 152.0
# Episode = 307 , Score = 157.0
# Episode = 308 , Score = 157.0
# Episode = 309 , Score = 143.0
# Episode = 310 , Score = 131.0
# Episode = 311 , Score = 23.0
# Episode = 312 , Score = 127.0
# Episode = 313 , Score = 27.0
# Episode = 314 , Score = 19.0
# Episode = 315 , Score = 112.0
# Episode = 316 , Score = 88.0
# Episode = 317 , Score = 14.0
# Episode = 318 , Score = 128.0
# Episode = 319 , Score = 125.0
# Episode = 320 , Score = 109.0
# Episode = 321 , Score = 93.0
# Episode = 322 , Score = 128.0
# Episode = 323 , Score = 111.0
# Episode = 324 , Score = 132.0
# Episode = 325 , Score = 136.0
# Episode = 326 , Score = 15.0
# Episode = 327 , Score = 56.0
# Episode = 328 , Score = 141.0
# Episode = 329 , Score = 145.0
# Episode = 330 , Score = 167.0
# Episode = 331 , Score = 200.0
# Episode = 332 , Score = 200.0
# Episode = 333 , Score = 200.0
# Episode = 334 , Score = 177.0
# Episode = 335 , Score = 149.0
# Episode = 336 , Score = 152.0
# Episode = 337 , Score = 119.0
# Episode = 338 , Score = 147.0
# Episode = 339 , Score = 39.0
# Episode = 340 , Score = 130.0
# Episode = 341 , Score = 200.0
# Episode = 342 , Score = 184.0
# Episode = 343 , Score = 195.0
# Episode = 344 , Score = 200.0
# Episode = 345 , Score = 200.0
# Episode = 346 , Score = 200.0
# Episode = 347 , Score = 200.0
# Episode = 348 , Score = 109.0
# Episode = 349 , Score = 152.0
# Episode = 350 , Score = 182.0
# Episode = 351 , Score = 135.0
# Episode = 352 , Score = 166.0
# Episode = 353 , Score = 146.0
# Episode = 354 , Score = 83.0
# Episode = 355 , Score = 107.0
# Episode = 356 , Score = 144.0
# Episode = 357 , Score = 156.0
# Episode = 358 , Score = 154.0
# Episode = 359 , Score = 167.0
# Episode = 360 , Score = 148.0
# Episode = 361 , Score = 72.0
# Episode = 362 , Score = 169.0
# Episode = 363 , Score = 124.0
# Episode = 364 , Score = 180.0
# Episode = 365 , Score = 179.0
# Episode = 366 , Score = 200.0
# Episode = 367 , Score = 124.0
# Episode = 368 , Score = 121.0
# Episode = 369 , Score = 187.0
# Episode = 370 , Score = 193.0
# Episode = 371 , Score = 122.0
# Episode = 372 , Score = 191.0
# Episode = 373 , Score = 179.0
# Episode = 374 , Score = 183.0
# Episode = 375 , Score = 49.0
# Episode = 376 , Score = 159.0
# Episode = 377 , Score = 157.0
# Episode = 378 , Score = 176.0
# Episode = 379 , Score = 168.0
# Episode = 380 , Score = 123.0
# Episode = 381 , Score = 163.0
# Episode = 382 , Score = 23.0
# Episode = 383 , Score = 157.0
# Episode = 384 , Score = 157.0
# Episode = 385 , Score = 141.0
# Episode = 386 , Score = 78.0
# Episode = 387 , Score = 149.0
# Episode = 388 , Score = 160.0
# Episode = 389 , Score = 184.0
# Episode = 390 , Score = 135.0
# Episode = 391 , Score = 160.0
# Episode = 392 , Score = 160.0
# Episode = 393 , Score = 148.0
# Episode = 394 , Score = 161.0
# Episode = 395 , Score = 145.0
# Episode = 396 , Score = 159.0
# Episode = 397 , Score = 145.0
# Episode = 398 , Score = 139.0
# Episode = 399 , Score = 143.0
# Episode = 400 , Score = 143.0
# Episode = 401 , Score = 148.0
# Episode = 402 , Score = 146.0
# Episode = 403 , Score = 150.0
# Episode = 404 , Score = 131.0
# Episode = 405 , Score = 183.0
# Episode = 406 , Score = 196.0
# Episode = 407 , Score = 163.0
# Episode = 408 , Score = 200.0
# Episode = 409 , Score = 178.0
# Episode = 410 , Score = 195.0
# Episode = 411 , Score = 174.0
# Episode = 412 , Score = 33.0
# Episode = 413 , Score = 190.0
# Episode = 414 , Score = 186.0
# Episode = 415 , Score = 172.0
# Episode = 416 , Score = 200.0
# Episode = 417 , Score = 155.0
# Episode = 418 , Score = 200.0
# Episode = 419 , Score = 200.0
# Episode = 420 , Score = 182.0
# Episode = 421 , Score = 172.0
# Episode = 422 , Score = 182.0
# Episode = 423 , Score = 200.0
# Episode = 424 , Score = 195.0
# Episode = 425 , Score = 163.0
# Episode = 426 , Score = 177.0
# Episode = 427 , Score = 178.0
# Episode = 428 , Score = 167.0
# Episode = 429 , Score = 158.0
# Episode = 430 , Score = 146.0
# Episode = 431 , Score = 161.0
# Episode = 432 , Score = 149.0
# Episode = 433 , Score = 130.0
# Episode = 434 , Score = 143.0
# Episode = 435 , Score = 128.0
# Episode = 436 , Score = 43.0
# Episode = 437 , Score = 147.0
# Episode = 438 , Score = 130.0
# Episode = 439 , Score = 118.0
# Episode = 440 , Score = 126.0
# Episode = 441 , Score = 123.0
# Episode = 442 , Score = 153.0
# Episode = 443 , Score = 155.0
# Episode = 444 , Score = 97.0
# Episode = 445 , Score = 153.0
# Episode = 446 , Score = 143.0
# Episode = 447 , Score = 177.0
# Episode = 448 , Score = 164.0
# Episode = 449 , Score = 148.0
# Episode = 450 , Score = 184.0
# Episode = 451 , Score = 198.0
# Episode = 452 , Score = 181.0
# Episode = 453 , Score = 169.0
# Episode = 454 , Score = 134.0
# Episode = 455 , Score = 179.0
# Episode = 456 , Score = 94.0
# Episode = 457 , Score = 179.0
# Episode = 458 , Score = 189.0
# Episode = 459 , Score = 169.0
# Episode = 460 , Score = 161.0
# Episode = 461 , Score = 140.0
# Episode = 462 , Score = 154.0
# Episode = 463 , Score = 153.0
# Episode = 464 , Score = 182.0
# Episode = 465 , Score = 186.0
# Episode = 466 , Score = 199.0
# Episode = 467 , Score = 190.0
# Episode = 468 , Score = 155.0
# Episode = 469 , Score = 200.0
# Episode = 470 , Score = 176.0
# Episode = 471 , Score = 159.0
# Episode = 472 , Score = 200.0
# Episode = 473 , Score = 200.0
# Episode = 474 , Score = 158.0
# Episode = 475 , Score = 175.0
# Episode = 476 , Score = 197.0
# Episode = 477 , Score = 190.0
# Episode = 478 , Score = 164.0
# Episode = 479 , Score = 200.0
# Episode = 480 , Score = 184.0
# Episode = 481 , Score = 196.0
# Episode = 482 , Score = 200.0
# Episode = 483 , Score = 200.0
# Episode = 484 , Score = 200.0
# Episode = 485 , Score = 184.0
# Episode = 486 , Score = 195.0
# Episode = 487 , Score = 190.0
# Episode = 488 , Score = 186.0
# Episode = 489 , Score = 173.0
# Episode = 490 , Score = 200.0
# Episode = 491 , Score = 161.0
# Episode = 492 , Score = 173.0
# Episode = 493 , Score = 156.0
# Episode = 494 , Score = 49.0
# Episode = 495 , Score = 180.0
# Episode = 496 , Score = 159.0
# Episode = 497 , Score = 153.0
# Episode = 498 , Score = 143.0
# Episode = 499 , Score = 150.0
# Episode = 500 , Score = 28.0
# Episode = 501 , Score = 148.0
# Episode = 502 , Score = 151.0
# Episode = 503 , Score = 154.0
# Episode = 504 , Score = 157.0
# Episode = 505 , Score = 111.0
# Episode = 506 , Score = 154.0
# Episode = 507 , Score = 150.0
# Episode = 508 , Score = 22.0
# Episode = 509 , Score = 174.0
# Episode = 510 , Score = 175.0
# Episode = 511 , Score = 200.0
# Episode = 512 , Score = 167.0
# Episode = 513 , Score = 176.0
# Episode = 514 , Score = 197.0
# Episode = 515 , Score = 169.0
# Episode = 516 , Score = 199.0
# Episode = 517 , Score = 200.0
# Episode = 518 , Score = 200.0
# Episode = 519 , Score = 200.0
# Episode = 520 , Score = 200.0
# Episode = 521 , Score = 200.0
# Episode = 522 , Score = 200.0
# Episode = 523 , Score = 200.0
# Episode = 524 , Score = 200.0
# Episode = 525 , Score = 200.0
# Episode = 526 , Score = 200.0
# Episode = 527 , Score = 200.0
# Episode = 528 , Score = 200.0
# Episode = 529 , Score = 200.0
# Episode = 530 , Score = 200.0
# Episode = 531 , Score = 200.0
# Episode = 532 , Score = 200.0
# Episode = 533 , Score = 200.0
# Episode = 534 , Score = 200.0
# Episode = 535 , Score = 200.0
# Episode = 536 , Score = 200.0
# Episode = 537 , Score = 200.0
# Episode = 538 , Score = 200.0
# Episode = 539 , Score = 200.0
# Episode = 540 , Score = 128.0
# Episode = 541 , Score = 200.0
# Episode = 542 , Score = 200.0
# Episode = 543 , Score = 200.0
# Episode = 544 , Score = 200.0
# Episode = 545 , Score = 200.0
# Episode = 546 , Score = 200.0
# Episode = 547 , Score = 200.0
# Episode = 548 , Score = 200.0
# Episode = 549 , Score = 200.0
# Episode = 550 , Score = 200.0
# Episode = 551 , Score = 200.0
# Episode = 552 , Score = 57.0
# Episode = 553 , Score = 200.0
# Episode = 554 , Score = 200.0
# Episode = 555 , Score = 200.0
# Episode = 556 , Score = 200.0
# Episode = 557 , Score = 200.0
# Episode = 558 , Score = 169.0
# Episode = 559 , Score = 197.0
# Episode = 560 , Score = 200.0
# Episode = 561 , Score = 169.0
# Episode = 562 , Score = 156.0
# Episode = 563 , Score = 158.0
# Episode = 564 , Score = 156.0
# Episode = 565 , Score = 98.0
# Episode = 566 , Score = 164.0
# Episode = 567 , Score = 163.0
# Episode = 568 , Score = 200.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-383d01d8bdce> in <module>()
#      16         next_q_values2 = model2(next_state)
#      17
# ---> 18         q_value = q_values[action].squeeze(0)
#      19         a = int(torch.max(next_q_values, 0)[1].numpy())
#      20         next_q_value = next_q_values2[a]
#
# KeyboardInterrupt:
